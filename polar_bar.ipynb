# %%
# %matplotlib inline

# %%
import matplotlib
matplotlib.axes.Axes.bar
matplotlib.pyplot.bar
matplotlib.projections.polar

import numpy as np
import matplotlib.pyplot as plt

# %%
# Compute pie slices
N = 365
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
height = 60
radii = 100 * np.random.rand(N)
width = np.pi / 200 * np.random.rand(N)
colors = plt.cm.viridis(radii / 10.)

ax.tick_params = ['JAN', 'FEB', 'MAR']
ax.set_xticklabels(ticks)

ax = plt.subplot(111, projection='polar')
ax.bar(theta, radii, width=width, bottom=0.0, color=colors, alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111,polar=True)

sample = np.random.uniform(low=0.5, high=13.3, size=(20,))
N = len(sample) 

theta = np.arange(0, 2*np.pi, 2*np.pi/N) 
bars = ax.bar(theta, sample, width=0.4)

ax.set_xticks(theta)
ax.set_xticklabels(range(1, len(theta)+1))
ax.yaxis.grid(True)
plt.show()
